# %%
from chatbot import load_source_to_document
file_base_path = "./source/user_1985947/"
all_documents=[]
all_json_doc = load_source_to_document(file_base_path, "json")
all_documents.extend(all_json_doc)
all_csv_doc = load_source_to_document(file_base_path, "csv")
all_documents.extend(all_csv_doc)

all_documents
# Out:
# ...
#  ...]

# %%
from chatbot import split_document

doc_splits = split_document(1000, 200, all_documents)

doc_splits
# Out:
# [Document(page_content='trade_number: 1\ngrowth: 0.0', metadata={'source': './source/user_1985947\\growth_data.csv', 'row': 0}),
#  Document(page_content='trade_number: 2\ngrowth: 0.0002', metadata={'source': './source/user_1985947\\growth_data.csv', 'row': 1}),
#  Document(page_content='trade_number: 3\ngrowth: 0.0004', metadata={'source': './source/user_1985947\\growth_data.csv', 'row': 2}),
#  Document(page_content='trade_number: 4\ngrowth: 0.0006', metadata={'source': './source/user_1985947\\growth_data.csv', 'row': 3}),
#  Document(page_content='trade_number: 5\ngrowth: 0.0008', metadata={'source': './source/user_1985947\\growth_data.csv', 'row': 4}),
#  Document(page_content='trade_number: 6\ngrowth: 0.001', metadata={'source': './source/user_1985947\\growth_data.csv', 'row': 5}),
#  Document(page_content='trade_number: 7\ngrowth: 0.0012', metadata={'source': './source/user_1985947\\growth_data.csv', 'row': 6}),
# ...
